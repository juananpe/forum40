# %%
import pandas as pd

# %%
df=pd.read_csv('performance.csv')

# %%
df
# Out:
#                 model_name                                   model_parameters  \
# 0     KNeighborsClassifier  KNeighborsClassifier(algorithm='auto', leaf_si...
# 1                      SVC  SVC(C=0.025, cache_size=200, class_weight='bal...
# 2                      SVC  SVC(C=1, cache_size=200, class_weight='balance...
# 3   DecisionTreeClassifier  DecisionTreeClassifier(class_weight='balanced'...
# 4   RandomForestClassifier  RandomForestClassifier(bootstrap=True, class_w...
# 5            MLPClassifier  MLPClassifier(activation='relu', alpha=1, batc...
# 6               GaussianNB       GaussianNB(priors=None, var_smoothing=1e-09)
# 7       LogisticRegression  LogisticRegression(C=1.0, class_weight='balanc...
# 8     KNeighborsClassifier  KNeighborsClassifier(algorithm='auto', leaf_si...
# 9                      SVC  SVC(C=0.025, cache_size=200, class_weight='bal...
# 10                     SVC  SVC(C=1, cache_size=200, class_weight='balance...
# ...

# %%
df.groupby('model_name').mean().sort_values('cross_val_f1_score',ascending=False)
# Out:
#                           time_stamp  cross_val_f1_score  cross_val_acc_score  \
# model_name
# LogisticRegression      1.568049e+09            0.643171             0.766345
# MLPClassifier           1.568049e+09            0.633571             0.793914
# GaussianNB              1.568049e+09            0.605627             0.697077
# KNeighborsClassifier    1.568048e+09            0.601282             0.781932
# RandomForestClassifier  1.568049e+09            0.589967             0.734283
# DecisionTreeClassifier  1.568049e+09            0.566057             0.659859
# SVC                     1.568049e+09            0.527369             0.766230
#
#                         time_to_fit  time_to_score
# model_name
# LogisticRegression        19.395649       0.004137
# MLPClassifier             12.978471       0.006407
# GaussianNB                 0.060947       0.012903
# KNeighborsClassifier       0.137729       5.034944
# RandomForestClassifier     0.050616       0.007755
# ...

# %%
import pandas as pd
import json
df=pd.read_csv('hyper_param.csv')
df
# Out:
#                                                model  \
# 0  LogisticRegression(C=1.0, class_weight=None, d...
# 1  LogisticRegression(C=1.0, class_weight=None, d...
# 2  LogisticRegression(C=1.0, class_weight=None, d...
# 3  LogisticRegression(C=1.0, class_weight=None, d...
# 4  LogisticRegression(C=1.0, class_weight=None, d...
# 5  LogisticRegression(C=1.0, class_weight=None, d...
# 6  LogisticRegression(C=1.0, class_weight=None, d...
# 7  LogisticRegression(C=1.0, class_weight=None, d...
# 8  LogisticRegression(C=1.0, class_weight=None, d...
#
#                                     model_parameters  optimized_score  \
# 0  {'C': 2.0, 'class_weight': 'balanced', 'l1_rat...         0.552033
# 1  {'C': 1.0, 'class_weight': 'balanced', 'l1_rat...         0.643140
# 2  {'C': 5.0, 'class_weight': 'balanced', 'l1_rat...         0.570391
# 3  {'C': 2.0, 'class_weight': 'balanced', 'l1_rat...         0.637380
# 4  {'C': 10.0, 'class_weight': 'balanced', 'l1_ra...         0.571638
# ...

# %%
label_name="offtopic"
model=None
model_parameter=None
for index,row in df.iterrows():
    if(row['label_name']==label_name):
        model=row['model']
        model_parameter=json.loads(row['model_parameters'].replace("'", "\""))

# %%
import json
json_acceptable_string = model_parameter.replace("'", "\"")
d = json.loads(json_acceptable_string)
d
# Out:
# {'C': 2.0,
#  'class_weight': 'balanced',
#  'l1_ratio': 0.5,
#  'max_iter': 100.0,
#  'penalty': 'elasticnet',
#  'solver': 'saga'}

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.set_params(**d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-fd806243ed24> in <module>
#       1 from sklearn.linear_model import LogisticRegression
#       2 model = LogisticRegression()
# ----> 3 model.set_params(**d)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/base.py in set_params(self, **params)
#     213                                  'Check the list of available parameters '
#     214                                  'with `estimator.get_params().keys()`.' %
# --> 215                                  (key, self))
#     216
#     217             if delim:
#
# ValueError: Invalid parameter l1_ratio for estimator LogisticRegression(C=2.0, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='warn', n_jobs=None, penalty='l2', random_state=None,
# ...

# %%
model.get_params().keys()
# Out:
# dict_keys(['C', 'class_weight', 'dual', 'fit_intercept', 'intercept_scaling', 'max_iter', 'multi_class', 'n_jobs', 'penalty', 'random_state', 'solver', 'tol', 'verbose', 'warm_start'])
